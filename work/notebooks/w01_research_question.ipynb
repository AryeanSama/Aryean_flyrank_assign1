# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/AryeanSama/Aryean_flyrank_assign1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# **Lane 2 — Refresh / Content Opportunity Scoring**
#
# I chose the Refresh / Content Opportunity Scoring lane because it focuses on identifying which content pages should be reviewed first for refresh, improvement, protection, pruning, or monitoring. This fits the starter dataset because it contains search, content, and engagement signals that can help prioritize pages for review. The goal is to create useful decision support rather than assume that a score guarantees future performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# The decision is which content pages should be reviewed first when review capacity is limited. The action could be to refresh, improve, protect, prune, or monitor a page based on the available evidence. A wrong recommendation could waste time reviewing a low-value page while an important page is missed. Therefore, the output should be treated as decision support rather than a guarantee of recovery.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
import os

# Updated path to fetch the CSV directly from its raw URL on GitHub
csv_path = "https://raw.githubusercontent.com/AryeanSama/Aryean_flyrank_assign1/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(csv_path)

print("Total pages:", len(df))
print("Median impressions (90d):", round(df["impressions_90d"].median(), 2))
print("Median clicks (90d):", round(df["clicks_90d"].median(), 2))
# Out:
# Total pages: 30000
# Median impressions (90d): 731.0
# Median clicks (90d): 1.0

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This analysis can identify observed patterns in the available content and performance data and can be used as decision support for prioritizing pages for review. It can show which pages or signals appear more relevant to refresh opportunities in this dataset. However, it cannot prove that a particular change will improve future performance, establish causal relationships, or predict how Google's ranking algorithm works.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
